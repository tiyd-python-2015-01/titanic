# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('figure', figsize=(16, 6))

# %%
# %matplotlib inline

# %%
train = pd.read_csv("train.csv")
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
female_train = train[(train.Sex == 'female')]
pd.pivot_table(female_train, index=["NarrowAge", "Pclass"], values=["Survived"]).plot(kind='barh')
#female_train.Age.plot(kind='hist')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.SibSp.unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
pd.pivot_table(train, index=["Sex", "SibSp", 'Pclass'], values=["Survived"]).plot(kind='barh', figsize=(6,6))
plt.axvline(x=0.5, linewidth=2, color='r')

# %%
pd.pivot_table(train, index=["Sex"], values=["Survived"]).plot(kind='barh')
plt.axvline(x=0.5, linewidth=2, color='r')

# %%
train['AgeRange'] = train['Age'].map(lambda x: 'adult' if x >= 18 else 'child')
pd.pivot_table(train, index=["Sex", 'AgeRange'], values=["Survived"]).plot(kind='barh')
plt.axvline(x=0.5, linewidth=2, color='r')

# %%
pd.pivot_table(train, index=["Embarked"], values=["Survived"]).plot(kind='barh')
plt.axvline(x=0.5, linewidth=2, color='r')

# %%
pd.pivot_table(train, index=["Embarked", "Sex", "AgeRange", "Pclass"], values=["Survived"]).plot(kind='barh')
plt.axvline(x=0.5, linewidth=2, color='r')

# %%
pd.pivot_table(train, index=["SibSp"], values=["Survived"]).plot(kind='barh')
plt.axvline(x=0.5, linewidth=2, color='r')

# %%
pd.pivot_table(train, index=["Sex", "Pclass", "AgeRange"], values=["Survived"]).plot(kind='barh')
plt.axvline(x=0.5, linewidth=2, color='r')

# %%
def ticket_price(fare):
    if fare < 10:
        return '< $10'
    elif fare < 20:
        return '$10-20'
    elif fare < 30:
        return '$20-30'
    else:
        return '> $30'
    
def narrow_age(age):
    if age > 75:
        return "Elder"
    elif age > 50:
        return "Old"
    elif age > 25:
        return "Adult"
    elif age > 18:
        return "Young adult"
    elif age > 13:
        return "Teenager"
    elif age > 8:
        return "Child"
    elif age > 5:
        return "Toddler"
    else:
        return "Baby"
    
train['NarrowAge'] = train["Age"].map(narrow_age)
    
train['TicketPrice'] = train['Fare'].map(ticket_price)
pd.pivot_table(train, index=["Sex", "Pclass", "TicketPrice", "AgeRange"], values=["Survived"]) \
    .plot(kind="barh")
plt.axvline(x=0.5, linewidth=2, color='r')

# %%
pd.pivot_table(train, index=["Sex", "NarrowAge", "Embarked"], values=["Survived"]).plot(kind="barh", figsize=(6,6))
plt.axvline(x=0.5, linewidth=2, color='r')

# %%
train["Gender"] = train["Sex"].map( {"female": 0, 'male': 1} ).astype(int)

# %%
pd.pivot_table(train, index=["Embarked", "Sex", "AgeRange", "Pclass"], values=["Survived"]).plot(kind='barh', figsize=(6,6))
plt.axvline(x=0.5, linewidth=2, color='r')

# %%
test = pd.read_csv("test.csv")
test.SibSp.unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 8])

# %%
test = pd.read_csv("test.csv")
test['AgeRange'] = test['Age'].map(lambda x: 'adult' if x >= 18 else 'child')
test['NarrowAge'] = test["Age"].map(narrow_age)
test['Survived'] = 0
test.loc[test["Sex"] == "female", "Survived"] = 1
test.loc[(test["Pclass"] == 2) & (test["Sex"] == "male") & (test["Embarked"] != "Q") & (test["AgeRange"] == 'child'), "Survived"] = 1
test.loc[(test["Pclass"] == 3) & (test["Fare"] > 20), "Survived"] = 0
test.loc[(test["Sex"] == 'female') & (test["NarrowAge"] == 'child') | (test["NarrowAge"] == 'toddler') & (test["Pclass"] == 3), "Survived"]= 0
test = test[["PassengerId", "Survived"]]
test.to_csv("genderclasschildmodel12.csv", index=False)

# %%
test.loc[(test["Pclass"] == 2) & (test["Sex"] == "male") & (test["Embarked"] != "S"), "Survived"] = 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-117-69ddfb1e2bdd> in <module>()
# ----> 1 test.loc[(test["Pclass"] == 2) & (test["Sex"] == "male") & (test["Embarked"] != "S"), "Survived"] = 1
#
# /Users/Bodandly/.pyenv/versions/sandbox/lib/python3.4/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1778             return self._getitem_multilevel(key)
#    1779         else:
# -> 1780             return self._getitem_column(key)
#    1781
#    1782     def _getitem_column(self, key):
#
# /Users/Bodandly/.pyenv/versions/sandbox/lib/python3.4/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1785         # get column
#    1786         if self.columns.is_unique:
# -> 1787             return self._get_item_cache(key)
#    1788
#    1789         # duplicate columns & possible reduce dimensionaility
#
# ...

# %%
test.loc[(test["Pclass"] == 2) & (test["Sex"] == "male") & (test["AgeRange"] == 'child') & (test["Fare"] > 10), "Survived"] = 1

# %%
median_ages = np.zeros((2,3))

for i in range(0, 2):
    for j in range(0, 3):
        median_ages[i,j] = train[(train["Gender"] == i) &\
                                 (train["Pclass"] == j+1)]["Age"].dropna().median()
median_ages

# %%
for i in range(0, 2):
    for j in range(0, 3):
        train.loc[(train.Age.isnull()) & (train.Gender == i) & (train.Pclass == j + 1),\
                  "AgeFill"] = median_ages[i,j]
train[ train['Age'].isnull() ][['Gender', 'Pclass', 'Age', 'AgeFill']].head()

# %%
train['AgeIsNull'] = pd.isnull(train.Age).astype(int)

# %%
def calc_median_ages(df):
    median_ages = np.zeros((2,3))
    
    for i in range(0, 2):
        for j in range(0, 3):
            median_ages[i, j] = df[(df["Gender"] == i) & \
                                   (df['Pclass'] == j+1)]['Age'].dropna().median()
    return median_ages


def guess_ages(df, median_ages=None):
    if median_ages is None:
        median_ages = calc_median_ages(df)
        
    for i in range(0, 2):
        for j in range(0, 3):
            df.loc[(df.Age.isnull()) & (df.Gender == i) & (df.Pclass == j+1),\
                   'Age'] = median_ages[i,j]
    
    df["GuessedAge"] = pd.isnull(df.Age).astype(int)
    return df

def clean(df, median_ages=None):
    df["Gender"] = df["Sex"].map( {"female": 0, 'male': 1} ).astype(int)
    df = guess_ages(df, median_ages)
    df = df.drop(["Ticket", "Cabin", 'Sex'], axis=1)
    
    return df
