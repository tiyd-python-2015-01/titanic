# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
# %matplotlib inline

# %%
train = pd.read_csv("train.csv")
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
pd.pivot_table(train, index=["Age"], values=["Survived"]).plot(kind="barh", figsize=(15,15))
plt.axvline(x=0.5, linewidth=2, color='r')
plt.show()

# %%
def age_breakdown(age):
    if age < 1:
        return "< 1"
    elif age < 10:
        return "1-10"
    elif age < 15:
        return "10-15"
    elif age < 20:
        return "15-20"
    elif age < 48:
        return "20-48"
    else:
        return "> 48"

# %%
train["Age"] = train["Age"].map(age_breakdown)

# %%
pd.pivot_table(train, index=["Age", "Sex", "Pclass"], values=["Survived"]).plot(kind="barh", figsize=(8,8))
plt.axvline(x=0.5, linewidth=2, color='r')

# %%
test = pd.read_csv("test.csv")

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
test["Survived"] = 0

# %%
test.loc[(test["Sex"] == "female") | (test["Age"] < 10), "Survived"] = 1

# %%
#test.head(30)

# %%
testexport = test[["PassengerId", "Survived"]]

# %%
testexport.to_csv("womenandchildrenmodel.csv", index=False)

# %%
test2 = pd.read_csv("test.csv")
test2["Survived"] = 0

# %%
test2.loc[(test2["Sex"] == "female") | (test2["Age"] < 10), "Survived"] = 1
test2.loc[(test2["Pclass"] == 3), "Survived"] = 0
test2.loc[(test2["Pclass"] == 1) & (test2["Sex"] == 'male') & (test2["Age"] < 15 ), "Survived"] = 1
test2.loc[(test2["Pclass"] == 3) & (test2["Sex"] == 'female') & (test2["Age"] > 15) & (test2["Age"] < 20), "Survived"] =1
test2.loc[test2["Age"] < 1, "Survived"] =1

# %%
#test2[(test2["Pclass"] == 3) & (test2["Sex"] == 'female') & (test2["Age"] > 15) & (test2["Age"] < 20)]

# %%
test2export = test2[["PassengerId", "Survived"]]

# %%
test2export.to_csv("augmentedwomanandchild.csv", index=False)

# %%
#test3 = test2.loc[test2["Age"] <= 13, "Survived"] = 1

# %%
test2[test2["Age"] ==10]
# Out:
#      PassengerId  Pclass                         Name     Sex  Age  SibSp  \
# 55           947       3         Rice, Master. Albert    male   10      4
# 140         1032       3  Goodwin, Miss. Jessie Allis  female   10      5
#
#      Parch   Ticket    Fare Cabin Embarked  Survived
# 55       1   382652  29.125   NaN        Q         0
# 140      2  CA 2144  46.900   NaN        S         0

# %%
test3export = test2[["PassengerId", "Survived"]]

# %%
test3export.to_csv("augmentedandunder13.csv", index=False)
